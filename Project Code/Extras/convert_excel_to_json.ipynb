# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel(r"C:\Users\Dell\Documents\GitHub\SU19CSE299S16G07NSU\Project Code\Data\List_of_NSU_graduates\Company Details.xlsx")
data = data.transpose()
data.to_excel("Transposed_company_details.xlsx")

# %%
data = pd.read_excel("Transposed_company_details.xlsx",index =False)

data
# Out:
#                                     Grameenphone Limited  \
# Address         GPHOUSE\nBashundhara,BaridharaDhaka-1229
# email                              info@grameenphone.com
# Contact Number                            880-1799882990
# Website                    https://www.grameenphone.com/
#
#                                 Robi Axiata Limited  \
# Address         53 Gulshan South Avenue, Dhaka 1212
# email                               123@robi.com.bd
# Contact Number                           1819400400
# Website                    https://www.robi.com.bd/
#
#                             Banglalink Digital Communications Ltd  \
# Address         Tiger’s Den, House 4 (SW), Bir Uttam Mir Shawk...
# email                                         info@banglalink.net
# Contact Number                                         1911304121
# Website                                https://www.banglalink.net
#
#                                       Teletalk Bangladesh Limited  \
# ...

# %%
json_data = data.to_dict()

# %%
# Out:
# 'GPHOUSE\nBashundhara,BaridharaDhaka-1229'

# %%
import json
with open('result.json', 'w') as fp:
    json.dump(json_data, fp)

# %%
#For testing purposes
file = open('result.json')
jsondata = json.load(file)

# %%
y =input()
x = jsondata[y]
x
# Out:
# Grameenphone Limited
# {'Address': 'GPHOUSE\nBashundhara,BaridharaDhaka-1229',
#  'email': 'info@grameenphone.com',
#  'Contact Number': '880-1799882990',
#  'Website': 'https://www.grameenphone.com/'}
